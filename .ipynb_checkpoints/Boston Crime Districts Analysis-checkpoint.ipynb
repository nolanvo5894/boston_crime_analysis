# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML, display_html
import datetime

# %%
crime_district = pd.read_csv('crime_district.csv')

# %%
crime_district.head()
# Out:
#    OFFENSE_CODE               OFFENSE_CODE_GROUP DISTRICT  \
# 0          3831  Motor Vehicle Accident Response       E5
# 1          3410                            Towed      C11
# 2          3006               Medical Assistance       B3
# 3           413               Aggravated Assault       B2
# 4           802                   Simple Assault       B2
#
#       OCCURRED_ON_DATE DAY_OF_WEEK  HOUR        DATE            DATE_HOUR
# 0  2019-04-14 16:00:00      Sunday    16  2019-04-14  2019-04-14 16:00:00
# 1  2019-04-16 20:25:00     Tuesday    20  2019-04-16  2019-04-16 21:00:00
# 2  2019-04-16 20:57:00     Tuesday    20  2019-04-16  2019-04-16 21:00:00
# 3  2019-04-16 20:52:00     Tuesday    20  2019-04-16  2019-04-16 21:00:00
# 4  2019-04-16 20:52:00     Tuesday    20  2019-04-16  2019-04-16 21:00:00

# %%
districts = crime_district['DISTRICT'].unique()

# %%
district_dfs = []

# %%
for i in range(len(districts)):
    df = crime_district[crime_district['DISTRICT'] == districts[i]].groupby('DATE').size()
    df.fillna(0, inplace = True)
    
    district_dfs.append(df)
    print(f'{districts[i]} has records for {df.shape[0]} days')
# Out:
# E5 has records for 1402 days
# C11 has records for 1402 days
# B3 has records for 1402 days
# B2 has records for 1402 days
# D14 has records for 1402 days
# D4 has records for 1402 days
# E13 has records for 1402 days
# A15 has records for 1388 days
# A7 has records for 1402 days
# A1 has records for 1402 days
# E18 has records for 1402 days
# C6 has records for 1402 days

# %%
# imputing days for district A15
start_date = crime_district['DATE'].min() 
end_date = crime_district['DATE'].max()
time_range = list(pd.date_range(start_date, end_date, freq = 'D'))

# %%
A15_df = district_dfs[7]

# %%
A15_count = []
for i in range(len(time_range)):
    try:
        A15_count.append(A15_df.loc[str(time_range[i].date())])
    except:
        A15_count.append(0)

# %%
district_dfs[7] = pd.Series(A15_count, index = time_range)

# %%
# plotting time series for all districts
fig, axes = plt.subplots(nrows = len(districts), figsize = (10, 30))
plt.subplots_adjust(hspace = 1)
for i in range(len(districts)):
    axes[i].plot(district_dfs[i][::21])
    axes[i].set(title = districts[i])

# %%
# hierarchical clustering of the time series
# define the distance metric to be Dynamic Time Warping
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
def get_dtw_distance(u, v):
    distance, path = fastdtw(u, v, dist = euclidean)
    return distance

# %%
# calculate the distance matrix
district_distance_matrix = np.ones((len(districts), len(districts)))

# %%
for i in range(len(districts)):
    for j in range(len(districts)):
        district_distance_matrix[i, j] = get_dtw_distance(district_dfs[i], district_dfs[j])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9cf8b2db6ff5> in <module>
#       1 for i in range(len(districts)):
#       2     for j in range(len(districts)):
# ----> 3         district_distance_matrix[i, j] = get_dtw_distance(district_dfs[i], district_dfs[j])
#
# <ipython-input-16-524f28a2bdb9> in get_dtw_distance(u, v)
#       4 from scipy.spatial.distance import euclidean
#       5 def get_dtw_distance(u, v):
# ----> 6     distance, path = fastdtw(u, v, dist = euclidean)
#       7     return distance
#
# ~/anaconda3/lib/python3.7/site-packages/fastdtw/fastdtw.py in fastdtw(x, y, radius, dist)
#      51     '''
#      52     x, y, dist = __prep_inputs(x, y, dist)
# ---> 53     return __fastdtw(x, y, radius, dist)
#      54
#      55
#
# ~/anaconda3/lib/python3.7/site-packages/fastdtw/fastdtw.py in __fastdtw(x, y, radius, dist)
#      71     y_shrinked = __reduce_by_half(y)
#      72     distance, path = \
# ---> 73         __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74     window = __expand_window(path, len(x), len(y), radius)
#      75     return __dtw(x, y, window, dist=dist)
#
# ~/anaconda3/lib/python3.7/site-packages/fastdtw/fastdtw.py in __fastdtw(x, y, radius, dist)
#      73         __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74     window = __expand_window(path, len(x), len(y), radius)
# ---> 75     return __dtw(x, y, window, dist=dist)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/fastdtw/fastdtw.py in __dtw(x, y, window, dist)
#     139     D[0, 0] = (0, 0, 0)
#     140     for i, j in window:
# --> 141         dt = dist(x[i-1], y[j-1])
#     142         D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
#     143                       (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/spatial/distance.py in euclidean(u, v, w)
#     596
#     597     """
# --> 598     return minkowski(u, v, p=2, w=w)
#     599
#     600
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/spatial/distance.py in minkowski(u, v, p, w)
#     499             root_w = np.power(w, 1/p)
#     500         u_v = root_w * u_v
# --> 501     dist = norm(u_v, ord=p)
#     502     return dist
#     503
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     135     """
#     136     # Differs from numpy only in non-finite handling and the use of blas.
# --> 137     a = np.asarray_chkfinite(a)
#     138
#     139     # Only use optimized norms if axis and keepdims are not specified.
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     457     """
#     458     a = asarray(a, dtype=dtype, order=order)
# --> 459     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     460         raise ValueError(
#     461             "array must not contain infs or NaNs")
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      44
#      45 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 46     return umr_all(a, axis, dtype, out, keepdims)
#      47
#      48 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:

# %%
district_distance_matrix

# %%
from sklearn.cluster import AgglomerativeClustering
