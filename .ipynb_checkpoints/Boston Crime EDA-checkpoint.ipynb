# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
crime = pd.read_csv('boston_crime.csv')

# %%
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I192028175          3831  Motor Vehicle Accident Response
# 1      I192028168          3410                            Towed
# 2      I192028167          3006               Medical Assistance
# 3      I192028166           413               Aggravated Assault
# 4      I192028166           802                   Simple Assault
#
#                      OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0  M/V - LEAVING SCENE - PROPERTY DAMAGE       E5            717      NaN
# 1                    TOWED MOTOR VEHICLE      C11            340      NaN
# 2          SICK/INJURED/MEDICAL - PERSON       B3            459      NaN
# 3         ASSAULT - AGGRAVATED - BATTERY       B2            291      NaN
# 4               ASSAULT SIMPLE - BATTERY       B2            291      NaN
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART      STREET  \
# ...

# %%
neighborhoods = pd.read_csv('boston_neighborhoods.csv')

# %%
neighborhoods.head()
# Out:
#    OBJECTID           Name        Acres  Neighborhood_ID  SqMiles  \
# 0        27     Roslindale  1605.568237               15     2.51
# 1        28  Jamaica Plain  2519.245394               11     3.94
# 2        29   Mission Hill   350.853564               13     0.55
# 3        30       Longwood   188.611947               28     0.29
# 4        31    Bay Village    26.539839               33     0.04
#
#     ShapeSTArea  ShapeSTLength
# 0  6.993827e+07   53563.912597
# 1  1.097379e+08   56349.937161
# 2  1.528312e+07   17918.724113
# 3  8.215904e+06   11908.757148
# 4  1.156071e+06    4650.635493

# %%
weather = pd.read_csv('boston_weather.csv')

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PGTM', 'PRCP', 'SNOW', 'TAVG',
#        'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT02', 'WT03',
#        'WT04', 'WT05', 'WT06', 'WT08', 'WT09'],
#       dtype='object')

# %%
['STATION', 'NAME', 'DATE', 'AWND', 'PGTM','PRCP', 'SNOW', 'TAVG',
       'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT01', 'WT02', 'WT03',
       'WT04', 'WT05', 'WT06', 'WT08', 'WT09']
